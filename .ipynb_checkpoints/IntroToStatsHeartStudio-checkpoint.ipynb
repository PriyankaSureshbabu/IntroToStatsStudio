# %% [markdown]
# ## Introduction to Stats in Python Studio
#
# We are going to be working with this [dataset](https://www.kaggle.com/andrewmvd/heart-failure-clinical-data) from Kaggle.  No need to download, as it is included in the git repository you just cloned.
# <br>
#
# Heart Disease is the number 1 cause of death globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worldwide.
# <br>
#
# Heart failure is a common event caused by heart disease and this dataset contains 12 features that can be used to predict mortality by heart failure. You are tasked to look at two particular variables and record your observations about their usefulness for predicting the probability of heart failure.
# <br>
#
# In section one, you will be asked to run some simple EDA and apply statistical terminology to describe each variable in more detail.  Section two will explore what the distribution of your variables looks like. Finally, in section three you will be asked to make some inferences about your variables and if you feel they are good indicators of predicting heart failure.
# <br>
#
# Answer the questions and record your observations in the space provided. Feel free to add more code blocks if you'd like.
# <br>

# %% [raw]
# Description of Data:
#
# Sex - Gender of patient Male = 1, Female =0
# Age - Age of patient
# Diabetes - 0 = No, 1 = Yes
# Anaemia - 0 = No, 1 = Yes
# High_blood_pressure - 0 = No, 1 = Yes
# Smoking - 0 = No, 1 = Yes
# DEATH_EVENT - 0 = No, 1 = Yes

# %%
# Import libries need with alias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')


# Set style and font size
sns.set_style('darkgrid')
sns.set(font_scale=1.5)

# %%
# Read in data to a dataframe
df = pd.read_csv('heart3.csv')

# %% [markdown]
# ## Section 1: First look at the data:
#
# Run some simple EDA and look at the data and your variables. Answer the following questions.

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %% [markdown]
# Which of our columns are catogorical data?Categorical columns are anaemia, diabetes, hbp, sex, smoking, time?, death event
#
# Which of our columns are continuous?The continuous columns are numerical and are age, cpk, ef, platelets, s-cre, s-sodium

# %% [markdown]
# ### Statistical interpretation of our data?
# #### First Variable:
# Mean, Min, Max, STD? Describe what this means.
# continuous Mean = average or sum/# values Min= lowest value Max= highest value STD = avg distance between each data point
#
# Mean = 60.83 = avg age participants/individuals min = 40 = lowest age max = 95 = highest age STD = 11.89 = average age difference between individuals
#
# <br><br><br>
#
#
# #### Second Variable:
# Mean, Min, Max, STD? Describe what this means.
#
# catagorical mean= 0.431 = there were slightly less individuals with anaemia than having it min = 0.0 = 0 means no anaemia max = 1.0 = 1 means positive for anaemia STD = 0.469 = avg diff between 0 and 1
# <br><br><br>
#
# What could the numbers in our categorical data tell us?
# The data is boolean yes/no
# <br><br><br>
#
# Why might we want to keep our categorical data as 1's and 0's? Why may we want to use something like the code below to change it?

# %%
df['sex'] = df.sex.replace({1: "Male", 0: "Female"})
df['anaemia'] = df.anaemia.replace({1: "Yes", 0: "No"})
df['diabetes'] = df.diabetes.replace({1: "Yes", 0: "No"})
df['high_blood_pressure'] = df.high_blood_pressure.replace({1: "Yes", 0: "No"})
df['smoking'] = df.smoking.replace({1: "Yes", 0: "No"})

df['DEATH_EVENT'] = df.DEATH_EVENT.replace({1: "Died", 0: "Alive"})
df.head()
# Out:
#     age anaemia  creatinine_phosphokinase diabetes  ejection_fraction  \
# 0  75.0      No                       582       No                 20
# 1  55.0      No                      7861       No                 38
# 2  65.0      No                       146       No                 20
# 3  50.0     Yes                       111       No                 20
# 4  65.0     Yes                       160      Yes                 20
#
#   high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# 0                 Yes  265000.00               1.9           130    Male
# 1                  No  263358.03               1.1           136    Male
# 2                  No  162000.00               1.3           129    Male
# 3                  No  210000.00               1.9           137    Male
# 4                  No  327000.00               2.7           116  Female
#
#   smoking  time DEATH_EVENT
# 0      No     4        Died
# 1      No     6        Died
# 2     Yes     7        Died
# 3      No     7        Died
# 4      No     8        Died

# %% [markdown]
# ## Section 2: Distribution of our data:

# %%
# Plot the distribution of your variable using distplot

# fig, ax = plt.subplots(figsize=(14,8))

# ax.set_ylabel('age')

# _ = df[['age', 'anaemia']].displot(by='anaemia', figsize=(13,8), vert=False, sym='b.', ax=ax)

df_dist=df['age'].dropna()
sns.distplot(df_dist)         
plt.show()

# %%
# Create boxplot to show distribution of variable

fig, ax = plt.subplots(figsize=(14,8))

ax.set_ylabel('age')

var = df[['age', 'anaemia']].boxplot(by='anaemia', figsize=(13,8), vert=False, sym='b.', ax=ax)

# %%
# Feel free to add any additional graphs that help you answer the questions below.

# %%
# Another way to check the skewness of our variable
df['age'].skew()
# Out:
# 0.42306190672863536

# %%
# Another way to check the kurtosis of our variable
df['age'].kurtosis()
# Out:
# -0.18487053195417413

# %% [markdown]
# ### Interpretation of how our data is distributed by variable?
# Looking at the above graphs, what can you tell about the distribution of your variables?Most participants are between ages 50-70 and the ones with anaemea are in the 52-68 range.
# <br><br><br><br><br>
# What is the skewness and kurtosis of your variables.  What does this mean?<br> Skewness is positive and small for age and that means... that there are a greater number of variable that are close together. A skewness between 1 and -1 is considered excellent. --> Kurtosis is positive and that means... that the curve is more flat and the variables more spread out. It is acceptable becuase it is more than -2 which would mean that its too flat.
# <br><br><br><br><br>
# What are some of the differences you note looking at a categorical variable vs a continuous variable?The chart isnt showing up for anaemia which is catagorical but it would just be 2 bars whereas the age is continuous and shows a distribition.
# <br><br><br><br><br>

# %% [markdown]
# ## Section 3: Finding Correlations
#
# Lets start by breaking our data into two.

# %%
# splitting the dataframe into 2 parts
# on basis of ‘DEATH_EVENT’ column values
df_died = df[df['DEATH_EVENT'] == 1 ]
df_lived = df[df['DEATH_EVENT'] == 0 ]
df.head()
# Out:
#     age anaemia  creatinine_phosphokinase diabetes  ejection_fraction  \
# 0  75.0      No                       582       No                 20
# 1  55.0      No                      7861       No                 38
# 2  65.0      No                       146       No                 20
# 3  50.0     Yes                       111       No                 20
# 4  65.0     Yes                       160      Yes                 20
#
#   high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# 0                 Yes  265000.00               1.9           130    Male
# 1                  No  263358.03               1.1           136    Male
# 2                  No  162000.00               1.3           129    Male
# 3                  No  210000.00               1.9           137    Male
# 4                  No  327000.00               2.7           116  Female
#
#   smoking  time DEATH_EVENT
# 0      No     4        Died
# 1      No     6        Died
# 2     Yes     7        Died
# 3      No     7        Died
# 4      No     8        Died

# %%
# Plot your variable based on if they died or lived

sns.distplot(df_died['1'])
sns.distplot(df_lived['0'])
plt.title("Chances of survival vs Died")
plt.legend(('Died','Lived'))
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Plot your variable based on if they died or lived
# ----> 3 sns.distplot(df_died['1'])
#       4 sns.distplot(df_lived['0'])
#       5 plt.title("Chances of survival vs Died")
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: '1'

# %%
# Feel free to add any additional graphs that help you answer the questions below.

# %% [markdown]
# #### What things can you infer if we consider our data a sample of the population, based on each of your variables.
# graph wont work. I would say that every health related event or disfunction has an increased risk with increaseing age
# <br><br><br><br><br>
# #### Do you think either of your variables is a good indicator for predicting Heart Failure, why or why not?
# <br><br><br><br><br>graph wont work. I would say age is a good predictor of heart failure becuase as age increases so does heart failure.
